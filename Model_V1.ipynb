# %% [markdown]
# # Import Library

# %%
pip install --upgrade tensorflow keras

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import re
import shutil
import cv2
import tensorflow as tf
import tensorflow_datasets as tfds
import keras

from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.layers import Rescaling, RandomFlip, RandomRotation, RandomZoom, RandomContrast, RandomTranslation, RandomBrightness
from keras.utils import plot_model
from matplotlib import pyplot as plt
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing import image, image_dataset_from_directory
from tensorflow.keras.applications.mobilenet import preprocess_input

# %% [markdown]
# # EDA

# %% [markdown]
# #### Load Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_dir = '/content/drive/MyDrive/Dataset_Capstone/faceshape_grey/train'

test_dir = '/content/drive/MyDrive/Dataset_Capstone/faceshape_grey/test'

val_dir = '/content/drive/MyDrive/Dataset_Capstone/faceshape_grey/validation'

# %%
from collections import Counter

def check_distribution(dir_path):
    class_counts = Counter()
    for class_name in os.listdir(dir_path):
        class_dir = os.path.join(dir_path, class_name)
        if os.path.isdir(class_dir):
            class_counts[class_name] = len(os.listdir(class_dir))
    return class_counts

print("Distribusi data di folder train:", check_distribution(train_dir))
print("Distribusi data di folder validation:", check_distribution(val_dir))
print("Distribusi data di folder test baru:", check_distribution(test_dir))
# Out:
# Distribusi data di folder train: Counter({'Square': 799, 'Heart': 798, 'Oblong': 798, 'Oval': 797, 'Round': 789})
# Distribusi data di folder validation: Counter({'Heart': 100, 'Oblong': 100, 'Square': 100, 'Round': 99, 'Oval': 99})
# Distribusi data di folder test baru: Counter({'Round': 100, 'Heart': 100, 'Oval': 100, 'Oblong': 100, 'Square': 100})

# %%
class_names = ['Oblong', 'Heart', 'Round', 'Square', 'Oval']

# %%
def create_datasets():
    train_ds = tf.keras.utils.image_dataset_from_directory(
        train_dir,
        seed=0,
        batch_size=32,
        label_mode='categorical',
        image_size=(224, 224),
        shuffle=True
    )

    validation_ds = tf.keras.utils.image_dataset_from_directory(
        val_dir,
        seed=0,
        batch_size=32,
        label_mode='categorical',
        image_size=(224, 224),
        shuffle=False
    )

    test_ds = tf.keras.utils.image_dataset_from_directory(
        test_dir,
        seed=0,
        batch_size=32,
        label_mode='categorical',
        image_size=(224, 224),
        shuffle=False
    )

    return train_ds, validation_ds, test_ds

# %%
# Create datasets with or without data augmentation
train_ds, validation_ds, test_ds = create_datasets()
# Out:
# Found 3981 files belonging to 5 classes.
# Found 498 files belonging to 5 classes.
# Found 500 files belonging to 5 classes.

# %%
# from tensorflow.keras.applications.vgg16 import VGG16

IMG_SHAPE = (224, 224, 3)

base_model = MobileNetV2(
    weights='imagenet',
    include_top=False,
    input_shape=IMG_SHAPE
)

tuning_layer_name = 'block_14_expand'
tuning_layer = base_model.get_layer(tuning_layer_name)
tuning_index = base_model.layers.index(tuning_layer)

# Membekukan semua layer sebelum tuning_layer
for layer in base_model.layers[:tuning_index]:
    layer.trainable = False


# base_model = VGG16(input_shape=IMG_SHAPE,
#                    include_top=False,
#                    weights='imagenet')

# for layer in base_model.layers:
#   layer.trainable = False

# Layer augmentasi
data_augmentation = tf.keras.Sequential([
    Rescaling(1./255),
    RandomFlip("horizontal"),
    RandomRotation(0.1),
    RandomZoom(0.2),
    RandomContrast(0.3),
    RandomTranslation(0.1, 0.1),
], name='data_augmentation')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
for i, layer in enumerate(base_model.layers):
    print(i, layer.name)

# %%
model = Sequential([
    data_augmentation,
    base_model,
    GlobalAveragePooling2D(),
    Dropout(0.5),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(len(class_names), activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ data_augmentation (Sequential)       │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ mobilenetv2_1.00_224 (Functional)    │ (None, 7, 7, 1280)          │       2,257,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ ?                           │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ ?                           │     0 (unbuilt) │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,257,984 (8.61 MB)
#  Trainable params: 1,526,080 (5.82 MB)
#  Non-trainable params: 731,904 (2.79 MB)

# %%
learning_rate = 0.0001

model.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    metrics=['accuracy']
)

class EarlyStoppingCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        if logs['accuracy']>0.95:
            self.model.stop_training = True
            print("\nReached 95% accuracy so cancelling training!")

early_stopping_callback = EarlyStoppingCallback()

# %%
history = model.fit(
    train_ds,
    epochs=70,
    verbose=1,
    validation_data=validation_ds,
    callbacks=[early_stopping_callback]
)
# Out:
# Epoch 1/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 972s 8s/step - accuracy: 0.2220 - loss: 2.3513 - val_accuracy: 0.2470 - val_loss: 1.7898
# Epoch 2/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 37s 137ms/step - accuracy: 0.3176 - loss: 1.9480 - val_accuracy: 0.3534 - val_loss: 1.5718
# Epoch 3/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 22s 147ms/step - accuracy: 0.3459 - loss: 1.8274 - val_accuracy: 0.3855 - val_loss: 1.5531
# Epoch 4/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 18s 141ms/step - accuracy: 0.3819 - loss: 1.6887 - val_accuracy: 0.3755 - val_loss: 1.5119
# Epoch 5/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 18s 146ms/step - accuracy: 0.4206 - loss: 1.6298 - val_accuracy: 0.4337 - val_loss: 1.5536
# Epoch 6/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 148ms/step - accuracy: 0.4561 - loss: 1.4928 - val_accuracy: 0.4257 - val_loss: 1.5815
# Epoch 7/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 147ms/step - accuracy: 0.4786 - loss: 1.4075 - val_accuracy: 0.4317 - val_loss: 1.6598
# Epoch 8/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 18s 146ms/step - accuracy: 0.5008 - loss: 1.3640 - val_accuracy: 0.5120 - val_loss: 1.4369
# Epoch 9/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 141ms/step - accuracy: 0.5269 - loss: 1.2401 - val_accuracy: 0.4759 - val_loss: 1.5326
# Epoch 10/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 22s 151ms/step - accuracy: 0.5604 - loss: 1.1946 - val_accuracy: 0.5482 - val_loss: 1.2011
# Epoch 11/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 17s 137ms/step - accuracy: 0.5823 - loss: 1.1336 - val_accuracy: 0.5221 - val_loss: 1.3192
# Epoch 12/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 17s 135ms/step - accuracy: 0.6067 - loss: 1.0794 - val_accuracy: 0.5382 - val_loss: 1.3946
# Epoch 13/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 18s 143ms/step - accuracy: 0.6095 - loss: 1.0516 - val_accuracy: 0.4518 - val_loss: 1.8975
# Epoch 14/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 18s 142ms/step - accuracy: 0.6360 - loss: 0.9694 - val_accuracy: 0.4679 - val_loss: 1.7934
# Epoch 15/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 17s 133ms/step - accuracy: 0.6483 - loss: 0.9654 - val_accuracy: 0.6024 - val_loss: 1.1573
# Epoch 16/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 17s 136ms/step - accuracy: 0.6610 - loss: 0.9360 - val_accuracy: 0.5743 - val_loss: 1.3552
# Epoch 17/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 18s 147ms/step - accuracy: 0.6724 - loss: 0.8532 - val_accuracy: 0.6205 - val_loss: 1.1913
# Epoch 18/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 19s 154ms/step - accuracy: 0.6911 - loss: 0.8459 - val_accuracy: 0.5863 - val_loss: 1.3207
# Epoch 19/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 18s 144ms/step - accuracy: 0.7059 - loss: 0.7898 - val_accuracy: 0.6486 - val_loss: 1.0616
# Epoch 20/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 19s 148ms/step - accuracy: 0.7152 - loss: 0.8029 - val_accuracy: 0.5582 - val_loss: 1.3187
# Epoch 21/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 152ms/step - accuracy: 0.7298 - loss: 0.7505 - val_accuracy: 0.6586 - val_loss: 1.0320
# Epoch 22/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 18s 145ms/step - accuracy: 0
70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 18s 147ms/step - accuracy: 0.8709 - loss: 0.3724 - val_accuracy: 0.7048 - val_loss: 1.1003
# Epoch 50/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 18s 145ms/step - accuracy: 0.8838 - loss: 0.3128 - val_accuracy: 0.6365 - val_loss: 1.3996
# Epoch 51/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 18s 146ms/step - accuracy: 0.8865 - loss: 0.3174 - val_accuracy: 0.6406 - val_loss: 1.6208
# Epoch 52/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 145ms/step - accuracy: 0.8857 - loss: 0.3169 - val_accuracy: 0.6767 - val_loss: 1.2839
# Epoch 53/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 145ms/step - accuracy: 0.8880 - loss: 0.3047 - val_accuracy: 0.6165 - val_loss: 1.5980
# Epoch 54/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 18s 142ms/step - accuracy: 0.9004 - loss: 0.2738 - val_accuracy: 0.5643 - val_loss: 1.8318
# Epoch 55/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.8951 - loss: 0.2717 - val_accuracy: 0.6747 - val_loss: 1.1860
# Epoch 56/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 18s 140ms/step - accuracy: 0.8938 - loss: 0.2703 - val_accuracy: 0.7048 - val_loss: 1.1478
# Epoch 57/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 144ms/step - accuracy: 0.9072 - loss: 0.2548 - val_accuracy: 0.6807 - val_loss: 1.3340
# Epoch 58/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 140ms/step - accuracy: 0.9055 - loss: 0.2628 - val_accuracy: 0.6406 - val_loss: 1.5562
# Epoch 59/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 147ms/step - accuracy: 0.9035 - loss: 0.2697 - val_accuracy: 0.7028 - val_loss: 1.2986
# Epoch 60/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 139ms/step - accuracy: 0.9236 - loss: 0.2346 - val_accuracy: 0.6586 - val_loss: 1.4185
# Epoch 61/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 137ms/step - accuracy: 0.9122 - loss: 0.2475 - val_accuracy: 0.6707 - val_loss: 1.3880
# Epoch 62/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 144ms/step - accuracy: 0.9010 - loss: 0.2736 - val_accuracy: 0.6325 - val_loss: 1.5010
# Epoch 63/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 19s 135ms/step - accuracy: 0.9247 - loss: 0.2210 - val_accuracy: 0.6325 - val_loss: 1.5288
# Epoch 64/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 139ms/step - accuracy: 0.9116 - loss: 0.2343 - val_accuracy: 0.6867 - val_loss: 1.2168
# Epoch 65/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 19s 149ms/step - accuracy: 0.9099 - loss: 0.2417 - val_accuracy: 0.6787 - val_loss: 1.4127
# Epoch 66/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 17s 135ms/step - accuracy: 0.9109 - loss: 0.2481 - val_accuracy: 0.6827 - val_loss: 1.3182
# Epoch 67/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 18s 144ms/step - accuracy: 0.9155 - loss: 0.2324 - val_accuracy: 0.7108 - val_loss: 1.1639
# Epoch 68/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 147ms/step - accuracy: 0.9225 - loss: 0.2210 - val_accuracy: 0.7129 - val_loss: 1.0241
# Epoch 69/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 144ms/step - accuracy: 0.9234 - loss: 0.1972 - val_accuracy: 0.7108 - val_loss: 1.2398
# Epoch 70/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 18s 145ms/step - accuracy: 0.9245 - loss: 0.2142 - val_accuracy: 0.7068 - val_loss: 1.0925

# %%
# Visualisasi akurasi
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='best')
plt.show()

# Visualisasi loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='best')
plt.show()

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import os

# test_dir2 = '/content/drive/MyDrive/Dataset_Capstone/extracted_faces/test'

# test_ds

# Dapatkan prediksi untuk data testing
y_pred = model.predict(test_ds)
y_pred = np.argmax(y_pred, axis=1)

# Dapatkan label sebenarnya untuk data testing
y_true = np.concatenate([y for x, y in test_ds], axis=0)
y_true = np.argmax(y_true, axis=1)

# Hitung dan print metrik
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

# You can print the metrics:
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 119s 7s/step
# Accuracy: 0.74
# Precision: 0.7495213193599567
# Recall: 0.74
# F1 Score: 0.738099316967385

# %%
# Data metrik
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-score']
values = [accuracy, precision, recall, f1]

# Membuat bar chart
plt.figure(figsize=(8, 6))
plt.bar(metrics, values, color=['blue', 'green', 'red', 'purple'])
plt.title('Model Performance Metrics')
plt.xlabel('Metric')
plt.ylabel('Score')
plt.ylim([0, 1])  # Mengatur batas sumbu y antara 0 dan 1

# Menambahkan label nilai di atas setiap bar
for i, v in enumerate(values):
    plt.text(i, v + 0.02, f'{v:.2f}', ha='center', va='bottom')

plt.show()

# %%
# Buat dan tampilkan confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
model.save('/content/drive/MyDrive/Model/Model_V1.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model_path = '/content/drive/MyDrive/Model_V1.keras'
tf.keras.models.save_model(
    model, filepath=model_path, overwrite=True, include_optimizer=True, save_format=None)

# %% [markdown]
# ## Convert to tfLite

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with open('/content/drive/MyDrive/Model/Model_V1.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# Saved artifact at '/tmp/tmpoooycxki'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_154')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   136048134802064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090411280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090402656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090403536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090405120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090413392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090562976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090562624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090412688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090564736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048134814208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090570016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090573360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090570720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090571424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090577936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090574416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090567728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090575120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090578112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090577056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090651056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090653872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090649648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090652112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090659680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090656160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090655456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090657392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090659504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090650000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090763280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090765920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090761872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090763808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090772256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090770496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090773312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090762224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090771552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090768208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090876736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090879200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090874624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090878144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090769440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090883952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090886592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090882544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090884480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090882896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090992304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090993360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090989136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090992656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090999696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090998640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048091001280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090988784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090999168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048091002688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048091055024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048091054320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048091003744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048091054144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048091004624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048091061360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048091064176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048091059952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048091062416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048091069984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048091066464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048091065760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048091067168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048091066112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048091060304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056293456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056296096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056292048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056293984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056302432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056300672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056298032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056292400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056301728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056298384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056390352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056392992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056388944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056390880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056299616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056397920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056400560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056396512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056398448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056396864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056488656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056491472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056487248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056489712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056497280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056496224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056498864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056486368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056496752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056487600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056617088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056619904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056615328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056618848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056626240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056624480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056627296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056615504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056625536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056629936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056681216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056680864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056629232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056682976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056623424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056688960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056691600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056687552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056689488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056694064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056779520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056778992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056696528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056779872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056693888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056785856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056788496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056784448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056786384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056695648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056790960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056790256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056791664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056790608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056793600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056882752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056885568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056881344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056883808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056891376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056890320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056892960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056880464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056890848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056881696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056996384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056999024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056994976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056996912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057005360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057003600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057006416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048056995328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057004656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057001312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057060512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057063152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057059104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057061040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057002544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057066672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057069312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057065264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057067200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057071776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057140848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057139616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057073360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057141200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057071600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057147184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057149824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057145776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057147712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057152640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057152288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057152464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057153696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055158208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048057154752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055163312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055166128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055161904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055164368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055171936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055168416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055167712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055169648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055171760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055162256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055276944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055279584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055275536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055277472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055287328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055282576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055282928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055283808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055286096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055283280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055375248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055377888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055373840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055375776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055285744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055381408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055384048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055380000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055381936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055380352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055471968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055473024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055468800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055472320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055479360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055478304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055480944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055468448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055478832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055483760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055551424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055550544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055553712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055553184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055560576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055558816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055561632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055550368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055559872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055564272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055664704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055664880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055565328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055666464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055557760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055672448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055675088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055671040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055672976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055677552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055676672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055677024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055678608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055714736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055677376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055726528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055728640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055720192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048090569136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055837344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055835408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055838400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055829776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136048055832592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136045953032688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136045953330592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136045953652112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136045953654400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136045953331472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136045953649296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136045953659680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136045953661792: TensorSpec(shape=(), dtype=tf.resource, name=None)
